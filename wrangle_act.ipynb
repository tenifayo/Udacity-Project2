# %% [markdown]
# # Project: Wrangling and Analyze Data

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
df1 = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
# import requests
# import os
# url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
# response = requests.get(url)

# with open("image_predictions.tsv", mode='w') as file:
#     file.write(response.text)

# %%
df2 = pd.read_csv("image_predictions.tsv",sep="\t")

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
# import tweepy

# consumer_key = '------------------'
# consumer_secret = '------------------'
# access_token = '-------------------------------'
# access_secret = '---------------------------'

# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_secret)

# api = tweepy.API(auth)

# %%
# import json
# from timeit import default_timer as timer

# %%
# tweet_ids = df1.tweet_id.values
# len(tweet_ids)

# # Query Twitter's API for JSON data for each tweet ID in the Twitter archive
# count = 0
# fails_dict = {}
# start = timer()
# # Save each tweet's returned JSON as a new line in a .txt file
# with open('tweet_json.txt', 'w') as outfile:
#     for tweet_id in tweet_ids:
#         count += 1
#         print(str(count) + ": " + str(tweet_id))
#         try:
#             tweet = api.get_status(tweet_id, tweet_mode='extended')
#             print("Success")
#             json.dump(tweet._json, outfile)
#             outfile.write('\n')
#         except tweepy.TweepyException as e:
#             print("Fail")
#             fails_dict[tweet_id] = e
#             pass
# end = timer()
# print(end - start)
# print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
tweetdata = []
with open('tweet_json.txt', 'r') as file:
    for line in file:
        data = json.loads(line)
        tweetdata.append(data)
df3 = pd.DataFrame(tweetdata, columns=['id', 'retweet_count', 'favorite_count'])

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# ### Assessing df1

# %%
df1.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
sum(df1.duplicated())
# Out:
# 0

# %%
df1.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %% [markdown]
# There seems to be outliers in rating_numerator and rating_denominator columns

# %%
df1[df1['rating_denominator'] > 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1433  697463031882764288                    NaN                  NaN
# ...

# %%
df1[df1['rating_denominator'] > 10]['text']
# Out:
# 342              @docmisterio account started on 11/15/15
# 433     The floofs have been released I repeat the flo...
# 784     RT @dog_rates: After so many requests, this is...
# 902     Why does this never happen at my front door......
# 1068    After so many requests, this is Bretagne. She ...
# 1120    Say hello to this unbelievably well behaved sq...
# 1165    Happy 4/20 from the squad! 13/10 for all https...
# 1202    This is Bluebert. He just saw that both #Final...
# 1228    Happy Saturday here's 9 puppers on a bench. 99...
# 1254    Here's a brigade of puppers. All look very pre...
# 1274    From left to right:\nCletus, Jerome, Alejandro...
# 1351    Here is a whole flock of puppers.  60/50 I'll ...
# 1433    Happy Wednesday here's a bucket of pups. 44/40...
# 1598    Yes I do realize a rating of 4/20 would've bee...
# 1634    Two sneaky puppers were not initially seen, mo...
# 1635    Someone help the girl is being mugged. Several...
# ...

# %%
df1[df1['rating_denominator'] < 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17           26259576.0
# 516   810984652412424192                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
#
#                       timestamp  \
# 313   2017-02-24 21:54:03 +0000
# 516   2016-12-19 23:06:23 +0000
# 2335  2015-11-16 16:11:11 +0000
#
#                                                  source  \
# 313   <a href="http://twitter.com/download/iphone" r...
# 516   <a href="http://twitter.com/download/iphone" r...
# 2335  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 313   @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
# 516   Meet Sam. She smiles 24/7 &amp; secretly aspir...                  NaN
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...                  NaN
#
# ...

# %% [markdown]
# This shows that the tweets with rating denominator greater than 10 are either not dog ratings, total ratings for a group of dogs or wrongly extracted.

# %%
df1['text'][2335]
# Out:
# 'This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv'

# %%
df1[df1['rating_numerator'] > 15]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 340   832215909146226688                    NaN                  NaN
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 763   778027034220126208                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 979   749981277374128128                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# ...

# %%
df1[df1['rating_numerator'] < 3]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 315   835152434251116546                    NaN                  NaN
# 605   798576900688019456                    NaN                  NaN
# 1016  746906459439529985           7.468859e+17         4.196984e+09
# 1446  696490539101908992           6.964887e+17         4.196984e+09
# 1761  678675843183484930                    NaN                  NaN
# 1764  678424312106393600                    NaN                  NaN
# 1869  675153376133427200                    NaN                  NaN
# 1920  674265582246694913                    NaN                  NaN
# 1940  673716320723169284           6.737159e+17         4.196984e+09
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2079  670826280409919488                    NaN                  NaN
# 2091  670783437142401025                    NaN                  NaN
# 2237  668142349051129856                    NaN                  NaN
# ...

# %%
df1['text'][2246]
# Out:
# "This is Tedrick. He lives on the edge. Needs someone to hit the gas tho. Other than that he's a baller. 10&amp;2/10 https://t.co/LvP1TTYSCN"

# %% [markdown]
# Rating denominators greater than 15 are either not dog ratings the total for a group of dogs or incorrect(i.e not properly extracted from text)

# %%
df1[~(df1.in_reply_to_status_id.isna())]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# ...                  ...                    ...                  ...
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 30    2017-07-15 16:51:35 +0000
# 55    2017-07-02 21:58:53 +0000
# 64    2017-06-27 12:14:36 +0000
# ...

# %%
df1['text'][64]
# Out:
# '@RealKentMurphy 14/10 confirmed'

# %%
df1[~(df1.retweeted_status_id.isnull())]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1023  746521445350707200                    NaN                  NaN
# 1043  743835915802583040                    NaN                  NaN
# 1242  711998809858043904                    NaN                  NaN
# 2259  667550904950915073                    NaN                  NaN
# 2260  667550882905632768                    NaN                  NaN
#
#                       timestamp  \
# 19    2017-07-21 01:02:36 +0000
# 32    2017-07-15 02:45:48 +0000
# 36    2017-07-13 01:35:06 +0000
# ...

# %% [markdown]
# Some of the tweets are retweets or replies

# %%
df1.doggo.unique()
# Out:
# array(['None', 'doggo'], dtype=object)

# %%
df1.pupper.unique()
# Out:
# array(['None', 'pupper'], dtype=object)

# %%
df1.floofer.value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df1.puppo.value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
df1.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
#           ...
# Hanz         1
# Karl         1
# Newt         1
# Ralphy       1
# Angel        1
# Name: name, Length: 957, dtype: int64

# %%
df1[df1["name"].str.islower()]["name"].value_counts()
# Out:
# a               55
# the              8
# an               7
# very             5
# just             4
# quite            4
# one              4
# mad              2
# getting          2
# not              2
# actually         2
# officially       1
# all              1
# unacceptable     1
# his              1
# old              1
# incredibly       1
# by               1
# infuriating      1
# light            1
# my               1
# such             1
# life             1
# space            1
# this             1
# Name: name, dtype: int64

# %%
df1[df1['name'] == 'officially']['text']
# Out:
# 1747    This is officially the greatest yawn of all ti...
# Name: text, dtype: object

# %%
df1[df1['expanded_urls'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 185   856330835276025856                    NaN                  NaN
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# ...

# %%
df1.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
df1[df1.floofer == 'floofer']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 46    883360690899218434                    NaN                  NaN
# 200   854010172552949760                    NaN                  NaN
# 582   800388270626521089                    NaN                  NaN
# 774   776218204058357768                    NaN                  NaN
# 984   749317047558017024                    NaN                  NaN
# 1022  746542875601690625                    NaN                  NaN
# 1091  737445876994609152                    NaN                  NaN
# 1110  733822306246479872                    NaN                  NaN
# 1534  689993469801164801                    NaN                  NaN
# 1614  685307451701334016                    NaN                  NaN
#
#                       timestamp  \
# 46    2017-07-07 16:22:55 +0000
# 200   2017-04-17 16:34:26 +0000
# 582   2016-11-20 17:20:08 +0000
# 774   2016-09-15 00:36:55 +0000
# 984   2016-07-02 19:01:20 +0000
# ...

# %%
df1[(df1.doggo == 'doggo') & (df1.floofer == 'floofer')]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760                    NaN                  NaN
#
#                      timestamp  \
# 200  2017-04-17 16:34:26 +0000
#
#                                                 source  \
# 200  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 200  At first I thought this was a shy doggo, but i...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 200                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 200  https://twitter.com/dog_rates/status/854010172...                11
#
#      rating_denominator  name  doggo  floofer pupper puppo
# 200                  10  None  doggo  floofer   None  None

# %%
df1[(df1.doggo == 'doggo') & (df1.puppo == 'puppo')]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952                    NaN                  NaN
#
#                      timestamp  \
# 191  2017-04-22 18:31:02 +0000
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 191  Here's a puppo participating in the #ScienceMa...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 191                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...                13
#
#      rating_denominator  name  doggo floofer pupper  puppo
# 191                  10  None  doggo    None   None  puppo

# %%
df1[(df1.doggo == 'doggo') & (df1.pupper == 'pupper')]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 460   817777686764523521                    NaN                  NaN
# 531   808106460588765185                    NaN                  NaN
# 565   802265048156610565           7.331095e+17         4.196984e+09
# 575   801115127852503040                    NaN                  NaN
# 705   785639753186217984                    NaN                  NaN
# 733   781308096455073793                    NaN                  NaN
# 778   775898661951791106                    NaN                  NaN
# 822   770093767776997377                    NaN                  NaN
# 889   759793422261743616                    NaN                  NaN
# 956   751583847268179968                    NaN                  NaN
# 1063  741067306818797568                    NaN                  NaN
# 1113  733109485275860992                    NaN                  NaN
#
#                       timestamp  \
# 460   2017-01-07 16:59:28 +0000
# ...

# %%
df1[(df1.floofer == 'floofer') & (df1.puppo == 'puppo')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1[(df1.floofer == 'floofer') & (df1.puppo == 'pupper')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1[(df1.floofer == 'puppo') & (df1.puppo == 'pupper')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### Assessing df2

# %%
df2.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 1413  771004394259247104    https://pbs.twimg.com/media/CrMmVqyWcAIDCHI.jpg
# 2006  877611172832227328    https://pbs.twimg.com/media/DCszHgmW0AAmIpT.jpg
# 1037  711998809858043904  https://pbs.twimg.com/tweet_video_thumb/CeGGkW...
# 68    667182792070062081    https://pbs.twimg.com/media/CUJPNjOWsAAZRqP.jpg
# 488   675517828909424640    https://pbs.twimg.com/media/CV_r3v4VAAALvwg.jpg
# 1820  834458053273591808    https://pbs.twimg.com/media/C5SXK89XUAQg7GX.jpg
# 1525  788412144018661376    https://pbs.twimg.com/media/CvEAqQoWgAADj5K.jpg
# 752   688116655151435777    https://pbs.twimg.com/media/CYyucekVAAESj8K.jpg
# 1086  718631497683582976    https://pbs.twimg.com/media/CfkXiX6W4AAmICF.jpg
# 1738  822244816520155136    https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg
#
#       img_num                   p1   p1_conf  p1_dog                  p2  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df2[(df2.p1_dog == True) | (df2.p2_dog == True) | (df2.p3_dog == True)]
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2069  891087950875897856  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#       img_num                        p1   p1_conf  p1_dog                  p2  \
# ...

# %%
df2.p1.value_counts()[:20]
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                      89
# Chihuahua                     83
# pug                           57
# chow                          44
# Samoyed                       43
# toy_poodle                    39
# Pomeranian                    38
# cocker_spaniel                30
# malamute                      30
# French_bulldog                26
# miniature_pinscher            23
# Chesapeake_Bay_retriever      23
# seat_belt                     22
# German_shepherd               20
# Staffordshire_bullterrier     20
# Siberian_husky                20
# web_site                      19
# Cardigan                      19
# Name: p1, dtype: int64

# %%
df2.p2.value_counts()[:20]
# Out:
# Labrador_retriever                104
# golden_retriever                   92
# Cardigan                           73
# Chihuahua                          44
# Pomeranian                         42
# Chesapeake_Bay_retriever           41
# French_bulldog                     41
# toy_poodle                         37
# cocker_spaniel                     34
# miniature_poodle                   33
# Siberian_husky                     33
# beagle                             28
# Eskimo_dog                         27
# collie                             27
# Pembroke                           27
# kuvasz                             26
# Italian_greyhound                  22
# Pekinese                           21
# American_Staffordshire_terrier     21
# chow                               20
# Name: p2, dtype: int64

# %%
df2.p3.value_counts()[:20]
# Out:
# Labrador_retriever                79
# Chihuahua                         58
# golden_retriever                  48
# Eskimo_dog                        38
# kelpie                            35
# kuvasz                            34
# Staffordshire_bullterrier         32
# chow                              32
# cocker_spaniel                    31
# beagle                            31
# toy_poodle                        29
# Pomeranian                        29
# Pekinese                          29
# Chesapeake_Bay_retriever          27
# Pembroke                          27
# Great_Pyrenees                    27
# French_bulldog                    26
# malamute                          26
# American_Staffordshire_terrier    24
# pug                               23
# Name: p3, dtype: int64

# %%
sum(df2.duplicated())
# Out:
# 0

# %%
df2.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df2[df2['p1'] == 'seat_belt']
# Out:
#                 tweet_id                                            jpg_url  \
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 108   667878741721415682    https://pbs.twimg.com/media/CUTILFiWcAE8Rle.jpg
# 198   669625907762618368    https://pbs.twimg.com/media/CUr9NjgU8AEpf5w.jpg
# 235   670427002554466305    https://pbs.twimg.com/media/CU3VzVwWwAAAsst.jpg
# 522   676582956622721024    https://pbs.twimg.com/media/CWO0m8tUwAAB901.jpg
# 551   677557565589463040    https://pbs.twimg.com/media/CWcrAVQWEAA6QMp.jpg
# 577   678740035362037760    https://pbs.twimg.com/media/CWtede2WIAAF_AJ.jpg
# 642   681339448655802368    https://pbs.twimg.com/media/CXSanNkWkAAqR9M.jpg
# 657   682303737705140231    https://pbs.twimg.com/media/CXgHoLnWAAA8i52.jpg
# 740   687312378585812992    https://pbs.twimg.com/media/CYnS9VWW8AAeR8m.jpg
# 843   695064344191721472  https://pbs.twimg.com/ext_tw_video_thumb/69506...
# ...

# %% [markdown]
# ### Assessing df3

# %%
df3
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           7010           33829
# 1     892177421306343426           5302           29343
# 2     891815181378084864           3482           22069
# 3     891689557279858688           7227           36955
# 4     891327558926688256           7766           35324
# ...                  ...            ...             ...
# 2216  666049248165822465             37              89
# 2217  666044226329800704            115             247
# 2218  666033412701032449             36             100
# 2219  666029285002620928             39             112
# 2220  666020888022790149            423            2294
#
# [2221 rows x 3 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2221 entries, 0 to 2220
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2221 non-null   int64
#  1   retweet_count   2221 non-null   int64
#  2   favorite_count  2221 non-null   int64
# dtypes: int64(3)
# memory usage: 52.2 KB

# %%
df3.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.221000e+03    2221.000000     2221.000000
# mean   7.412594e+17    2469.719946     7114.590275
# std    6.972507e+16    4232.450106    11153.480508
# min    6.660209e+17       1.000000        0.000000
# 25%    6.769755e+17     477.000000     1166.000000
# 50%    7.119681e+17    1128.000000     2969.000000
# 75%    8.008594e+17    2875.000000     8860.000000
# max    8.924206e+17   70791.000000   144957.000000

# %%
sum(df3.duplicated())
# Out:
# 0

# %% [markdown]
# ### Quality issues
# `df1` table
# 1. Some tweets are either retweets or replies(which do not have images).
#
# 2. Some tweets have invalid rating denominators(not equal to 10).
#
# 3. Some rating numerators are invalid (too large).
#
# 4. The source column contains html tags.
#
# 5. Some tweets have more than 1 dog stage.
#
# 6. Erroneous datatypes of tweet_id and timestamp columns
#
# `df2` table
# 7.  Erroneous datatypes of tweet_id and img_num columns.
#
# 8. Some tweets have images that do not contain dogs.
#
# `df3` table
# 9. Erroneous datatype of id column.

# %% [markdown]
# ### Tidiness issues
# 1. Dog stages are in four columns instead of one
#
# 2. df1, df2 and df3 should form a single table

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
df1_copy = df1.copy()
df2_copy = df2.copy()
df3_copy = df3.copy()

# %% [markdown]
# ### Issue #1: Some tweets are either retweets or replies(which do not have images)

# %% [markdown]
# #### Define:
# Delete the rows where `retweeted_status_id` and `in_reply_to_status_id` is not null and then drop `retweeted_status_id`, `retweeted_status_user_id`, `retweeted_status_timestamp`,`in_reply_to_status_id` and `in_reply_to_user_id` columns.

# %% [markdown]
# #### Code

# %%
df1_copy = df1_copy[df1_copy['retweeted_status_id'].isna()]
df1_copy = df1_copy[df1_copy['in_reply_to_status_id'].isna()]
df1_copy.drop(['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp','in_reply_to_status_id','in_reply_to_user_id'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
df1_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Issue #2: Some tweets have invalid rating denominators(not equal to 10)

# %% [markdown]
# #### Define
# Check the `text` column and assign the correct ratings(both numerator and denominator) and drop the tweets that are not dog ratings

# %% [markdown]
# #### Code

# %%
df1_copy[df1_copy['rating_denominator'] > 10][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id                                               text  \
# 433   820690176645140481  The floofs have been released I repeat the flo...
# 902   758467244762497024  Why does this never happen at my front door......
# 1068  740373189193256964  After so many requests, this is Bretagne. She ...
# 1120  731156023742988288  Say hello to this unbelievably well behaved sq...
# 1165  722974582966214656  Happy 4/20 from the squad! 13/10 for all https...
# 1202  716439118184652801  This is Bluebert. He just saw that both #Final...
# 1228  713900603437621249  Happy Saturday here's 9 puppers on a bench. 99...
# 1254  710658690886586372  Here's a brigade of puppers. All look very pre...
# 1274  709198395643068416  From left to right:\nCletus, Jerome, Alejandro...
# 1351  704054845121142784  Here is a whole flock of puppers.  60/50 I'll ...
# 1433  697463031882764288  Happy Wednesday here's a bucket of pups. 44/40...
# ...

# %%
df1_copy.loc[df1_copy.tweet_id == 820690176645140481,'rating_numerator'] = 12
df1_copy.loc[df1_copy.tweet_id == 820690176645140481,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 758467244762497024,'rating_numerator'] = 11
df1_copy.loc[df1_copy.tweet_id == 758467244762497024,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 740373189193256964,'rating_numerator'] = 14
df1_copy.loc[df1_copy.tweet_id == 740373189193256964,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 731156023742988288,'rating_numerator'] = 12
df1_copy.loc[df1_copy.tweet_id == 731156023742988288,'rating_denominator'] =  10

df1_copy.loc[df1_copy.tweet_id == 722974582966214656,'rating_numerator'] = 13
df1_copy.loc[df1_copy.tweet_id == 722974582966214656,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 716439118184652801,'rating_numerator'] = 11
df1_copy.loc[df1_copy.tweet_id == 716439118184652801,'rating_denominator']  = 10

df1_copy.loc[df1_copy.tweet_id == 713900603437621249,'rating_numerator']= 11
df1_copy.loc[df1_copy.tweet_id == 713900603437621249,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 710658690886586372,'rating_numerator'] = 10
df1_copy.loc[df1_copy.tweet_id == 710658690886586372,'rating_denominator']  = 10

df1_copy.loc[df1_copy.tweet_id == 709198395643068416,'rating_numerator'] = 9
df1_copy.loc[df1_copy.tweet_id == 709198395643068416,'rating_denominator']  = 10

df1_copy.loc[df1_copy.tweet_id == 704054845121142784,'rating_numerator'] = 12
df1_copy.loc[df1_copy.tweet_id == 704054845121142784,'rating_denominator']  = 10

df1_copy.loc[df1_copy.tweet_id == 697463031882764288,'rating_numerator'] = 11
df1_copy.loc[df1_copy.tweet_id == 697463031882764288,'rating_denominator']  = 10

df1_copy.loc[df1_copy.tweet_id == 684222868335505415,'rating_numerator'] = 11
df1_copy.loc[df1_copy.tweet_id == 684222868335505415,'rating_denominator']  = 10     

df1_copy.loc[df1_copy.tweet_id == 682962037429899265,'rating_numerator'] = 10
df1_copy.loc[df1_copy.tweet_id == 682962037429899265,'rating_denominator']  = 10    

df1_copy.loc[df1_copy.tweet_id == 677716515794329600,'rating_numerator'] = 12
df1_copy.loc[df1_copy.tweet_id == 677716515794329600,'rating_denominator']  = 10    

df1_copy.loc[df1_copy.tweet_id == 675853064436391936,'rating_numerator'] = 11
df1_copy.loc[df1_copy.tweet_id == 675853064436391936,'rating_denominator']  = 10

# %%
df1_copy[['tweet_id','text','rating_numerator','rating_denominator']][df1_copy['rating_denominator'] < 10]
# Out:
#                 tweet_id                                               text  \
# 516   810984652412424192  Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 2335  666287406224695296  This is an Albanian 3 1/2 legged  Episcopalian...
#
#       rating_numerator  rating_denominator
# 516                 24                   7
# 2335                 1                   2

# %%
df1_copy = df1_copy[~(df1_copy['rating_denominator'] < 10)]

# %% [markdown]
# #### Test

# %%
df1_copy[df1_copy['rating_denominator'] > 10]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1_copy[df1_copy['rating_denominator'] < 10]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### Issue #3: Some rating numerators are invalid

# %% [markdown]
# #### Define
# Filter out the rows with rating numerators greater 15 or equal to zero

# %% [markdown]
# #### Code

# %%
df1_copy[df1_copy['rating_numerator'] > 17][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id                                               text  \
# 695   786709082849828864  This is Logan, the Chow who lived. He solemnly...
# 763   778027034220126208  This is Sophie. She's a Jubilant Bush Pupper. ...
# 979   749981277374128128  This is Atticus. He's quite simply America af....
# 1712  680494726643068929  Here we have uncovered an entire battalion of ...
# 2074  670842764863651840  After so many requests... here you go.\n\nGood...
#
#       rating_numerator  rating_denominator
# 695                 75                  10
# 763                 27                  10
# 979               1776                  10
# 1712                26                  10
# 2074               420                  10

# %%
df1_copy.loc[df1_copy.tweet_id == 666287406224695296,'rating_numerator'] = 9
df1_copy.loc[df1_copy.tweet_id == 666287406224695296,'rating_denominator'] = 10

df1_copy.loc[df1_copy.tweet_id == 786709082849828864,'rating_numerator'] = 9.75

df1_copy.loc[df1_copy.tweet_id == 778027034220126208,'rating_numerator'] = 11.27

df1_copy.loc[df1_copy.tweet_id == 680494726643068929,'rating_numerator'] = 11.26

# %%
 df1_copy = df1_copy[~(df1_copy['rating_numerator'] > 17)]

# %%
 df1_copy = df1_copy[~(df1_copy['rating_numerator'] == 0)]

# %% [markdown]
# #### Test

# %%
df1_copy[df1_copy['rating_numerator'] > 17]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### Issue #4: The `source` column contains html tags

# %% [markdown]
# #### Define
# Extract the source from the html tags using str.extract()

# %% [markdown]
# #### Code

# %%
df1_copy['source'] = df1_copy['source'].str.extract('^<a.+>(.+)</a>$')

# %% [markdown]
# #### Test

# %%
df1_copy['source'].value_counts()
# Out:
# Twitter for iPhone     1960
# Vine - Make a Scene      91
# Twitter Web Client       31
# TweetDeck                10
# Name: source, dtype: int64

# %% [markdown]
# ### Issue #5: Some tweets have more than 1 dog stage

# %% [markdown]
# #### Define
# Check `text` column to know which dog stage to keep and assign the extra dog stage to 'None'

# %% [markdown]
# #### Code

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.floofer == 'floofer')]
# Out:
#                tweet_id                  timestamp              source  \
# 200  854010172552949760  2017-04-17 16:34:26 +0000  Twitter for iPhone
#
#                                                   text  \
# 200  At first I thought this was a shy doggo, but i...
#
#                                          expanded_urls  rating_numerator  \
# 200  https://twitter.com/dog_rates/status/854010172...              11.0
#
#      rating_denominator  name  doggo  floofer pupper puppo
# 200                  10  None  doggo  floofer   None  None

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.puppo == 'puppo')]
# Out:
#                tweet_id                  timestamp              source  \
# 191  855851453814013952  2017-04-22 18:31:02 +0000  Twitter for iPhone
#
#                                                   text  \
# 191  Here's a puppo participating in the #ScienceMa...
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...              13.0
#
#      rating_denominator  name  doggo floofer pupper  puppo
# 191                  10  None  doggo    None   None  puppo

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.pupper == 'pupper')]
# Out:
#                 tweet_id                  timestamp               source  \
# 460   817777686764523521  2017-01-07 16:59:28 +0000   Twitter for iPhone
# 531   808106460588765185  2016-12-12 00:29:28 +0000   Twitter for iPhone
# 575   801115127852503040  2016-11-22 17:28:25 +0000   Twitter for iPhone
# 705   785639753186217984  2016-10-11 00:34:48 +0000   Twitter for iPhone
# 733   781308096455073793  2016-09-29 01:42:20 +0000  Vine - Make a Scene
# 889   759793422261743616  2016-07-31 16:50:42 +0000   Twitter for iPhone
# 956   751583847268179968  2016-07-09 01:08:47 +0000   Twitter for iPhone
# 1063  741067306818797568  2016-06-10 00:39:48 +0000   Twitter for iPhone
# 1113  733109485275860992  2016-05-19 01:38:16 +0000   Twitter for iPhone
#
#                                                    text  \
# 460   This is Dido. She's playing the lead role in "...
# 531   Here we have Burke (pupper) and Dexter (doggo)...
# 575   This is Bones. He's being haunted by another d...
# ...

# %%
df1_copy['text'][1113]
# Out:
# 'Like father (doggo), like son (pupper). Both 12/10 https://t.co/pG2inLaOda'

# %%
df1_copy.loc[df1_copy.tweet_id == 854010172552949760,'doggo'] = 'None'

df1_copy.loc[df1_copy.tweet_id == 855851453814013952,'doggo'] = 'None'

df1_copy.loc[df1_copy.tweet_id == 817777686764523521,'doggo'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 808106460588765185,'pupper'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 801115127852503040,'doggo'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 785639753186217984,'pupper'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 781308096455073793,'doggo'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 759793422261743616,'pupper'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 751583847268179968,'doggo'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 751583847268179968,'pupper'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 741067306818797568,'pupper'] = 'None'
df1_copy.loc[df1_copy.tweet_id == 733109485275860992,'pupper'] = 'None'

# %% [markdown]
# #### Test

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.floofer == 'floofer')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.puppo == 'puppo')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1_copy[(df1_copy.doggo == 'doggo') & (df1_copy.pupper == 'pupper')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df1_copy.loc[1120,'doggo'] = 'doggo'

# %%
df1_copy['text'][1049]
# Out:
# 'This is a very rare Great Alaskan Bush Pupper. Hard to stumble upon without spooking. 12/10 would pet passionately https://t.co/xOBKCdpzaa'

# %% [markdown]
# ### Issue #6: Erroneous datatype of `tweet_id` and `timestamp` columns

# %% [markdown]
# #### Define
# Convert `tweet_id` datatype to string using astype() and convert `timestamp` to datetime using pandas to_datetime()

# %% [markdown]
# #### Code

# %%
df1_copy['tweet_id'] = df1_copy['tweet_id'].astype(str)

df1_copy['timestamp'] = pd.to_datetime(df1_copy['timestamp'])

# %% [markdown]
# #### Test

# %%
df1_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2092 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2092 non-null   object
#  1   timestamp           2092 non-null   datetime64[ns, UTC]
#  2   source              2092 non-null   object
#  3   text                2092 non-null   object
#  4   expanded_urls       2089 non-null   object
#  5   rating_numerator    2092 non-null   float64
#  6   rating_denominator  2092 non-null   int64
#  7   name                2092 non-null   object
#  8   doggo               2092 non-null   object
#  9   floofer             2092 non-null   object
#  10  pupper              2092 non-null   object
#  11  puppo               2092 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(9)
# memory usage: 292.5+ KB

# %% [markdown]
# ### Issue #7: Some tweets have images that do not contain dogs

# %% [markdown]
# #### Define
# Remove tweets whose images do not contain dog(i.e where `p1_dog`, `p2_dog` and `p3_dog` are FALSE). Assign p1, p2 or p3 to a new column called breed and the corresponding confidence to a new column called conf. Then drop `p1`,`p1_conf`,`p1_dog`,`p2`,`p2_conf`,`p2_dog`,`p3`,`p3_conf` and `p3_dog` columns.

# %% [markdown]
# #### Code

# %%
dog1 = df2_copy[df2_copy.p1_dog == True]
dog2 = df2_copy[(df2_copy.p1_dog == False) & (df2_copy.p2_dog == True)]
dog3 = df2_copy[(df2_copy.p1_dog == False) & (df2_copy.p2_dog == False) & (df2_copy.p3_dog == True)]

# %%
dog1['breed'] = dog1.p1
dog1['conf'] = dog1.p1_conf

dog2['breed'] = dog2.p2
dog2['conf'] = dog2.p2_conf

dog3['breed'] = dog3.p3
dog3['conf'] = dog3.p3_conf

# %%
df2_copy = pd.concat([dog1,dog2,dog3])
df2_copy.drop(['p1','p1_conf','p1_dog','p2','p2_conf','p2_dog','p3','p3_conf','p3_dog'],axis=1,inplace=True)

# %% [markdown]
# #### Test

# %%
df2_copy.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                   breed      conf
# 0        1  Welsh_springer_spaniel  0.465074
# 1        1                 redbone  0.506826
# 2        1         German_shepherd  0.596461
# 3        1     Rhodesian_ridgeback  0.408143
# 4        1      miniature_pinscher  0.560311

# %% [markdown]
# ### Issue #8: Erroneous datatypes of `tweet_id` and `img_num` columns in df2_copy

# %% [markdown]
# #### Define
# Convert the datatype of `tweet_id` to string and `img_num` to category using astype()

# %% [markdown]
# #### Code

# %%
df2_copy.tweet_id = df2_copy.tweet_id.astype(str)
df2_copy.img_num = df2_copy.img_num.astype('category')

# %% [markdown]
# #### Test

# %%
df2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2026
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  1751 non-null   object
#  1   jpg_url   1751 non-null   object
#  2   img_num   1751 non-null   category
#  3   breed     1751 non-null   object
#  4   conf      1751 non-null   float64
# dtypes: category(1), float64(1), object(3)
# memory usage: 70.3+ KB

# %% [markdown]
# ### Issue #9: Erroneous datatypes of `id` column in df_tweets table

# %% [markdown]
# #### Define

# %% [markdown]
# #### Code

# %%
df3_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2221 entries, 0 to 2220
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2221 non-null   int64
#  1   retweet_count   2221 non-null   int64
#  2   favorite_count  2221 non-null   int64
# dtypes: int64(3)
# memory usage: 52.2 KB

# %%
df3_copy.id = df3_copy.id.astype(str)

# %% [markdown]
# #### Test

# %%
df3_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2221 entries, 0 to 2220
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2221 non-null   object
#  1   retweet_count   2221 non-null   int64
#  2   favorite_count  2221 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 52.2+ KB

# %% [markdown]
# ### Issue #10: Dog stages are in four columns instead of one

# %% [markdown]
# #### Define
# Create a dog_stage column and assign values to it based on the values in `doggo`, `floofer`, `puppo` and `pupper` columns and then drop them. Then fill null with 'Unknown'.

# %% [markdown]
# #### Code

# %%
stages = df1_copy[['doggo','floofer','puppo','pupper']]

# %%
stages.shape
# Out:
# (2092, 4)

# %%
stages['doggo'].value_counts()
# Out:
# None     2014
# doggo      78
# Name: doggo, dtype: int64

# %%
stages.loc[stages.doggo == 'doggo','dog_stage'] = 'doggo'
stages.loc[stages.floofer == 'floofer','dog_stage'] = 'floofer'
stages.loc[stages.pupper == 'pupper','dog_stage'] = 'pupper'
stages.loc[stages.puppo == 'puppo','dog_stage'] = 'puppo'

# %%
stages.dog_stage.fillna('Unknown', inplace=True)

# %%
stages
# Out:
#      doggo floofer puppo pupper dog_stage
# 0     None    None  None   None   Unknown
# 1     None    None  None   None   Unknown
# 2     None    None  None   None   Unknown
# 3     None    None  None   None   Unknown
# 4     None    None  None   None   Unknown
# ...    ...     ...   ...    ...       ...
# 2351  None    None  None   None   Unknown
# 2352  None    None  None   None   Unknown
# 2353  None    None  None   None   Unknown
# 2354  None    None  None   None   Unknown
# 2355  None    None  None   None   Unknown
#
# [2092 rows x 5 columns]

# %%
stages.dog_stage.value_counts()
# Out:
# Unknown    1756
# pupper      224
# doggo        78
# puppo        24
# floofer      10
# Name: dog_stage, dtype: int64

# %%
df1_copy['dog_stage'] = stages.dog_stage

# %%
df1_copy.sample(10)
# Out:
#                 tweet_id                 timestamp              source  \
# 2175  669214165781868544 2015-11-24 18:01:05+00:00  Twitter for iPhone
# 2282  667211855547486208 2015-11-19 05:24:37+00:00  Twitter for iPhone
# 758   778408200802557953 2016-09-21 01:39:11+00:00  Twitter for iPhone
# 1297  707776935007539200 2016-03-10 03:55:45+00:00  Twitter for iPhone
# 901   758474966123810816 2016-07-28 01:31:38+00:00  Twitter for iPhone
# 1135  728409960103686147 2016-05-06 02:24:02+00:00  Twitter for iPhone
# 920   756303284449767430 2016-07-22 01:42:09+00:00  Twitter for iPhone
# 1429  697596423848730625 2016-02-11 01:42:02+00:00  Twitter for iPhone
# 1609  685547936038666240 2016-01-08 19:45:39+00:00  Twitter for iPhone
# 517   810896069567610880 2016-12-19 17:14:23+00:00  Twitter for iPhone
#
#                                                    text  \
# 2175  This is Jaspers. He is a northeastern Gillette...
# 2282  This is Genevieve. She is a golden retriever c...
# ...

# %%
df1_copy.drop(['doggo','floofer','puppo','pupper'], axis=1,inplace=True)

# %% [markdown]
# #### Test

# %%
 df1_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2092 entries, 0 to 2355
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2092 non-null   object
#  1   timestamp           2092 non-null   datetime64[ns, UTC]
#  2   source              2092 non-null   object
#  3   text                2092 non-null   object
#  4   expanded_urls       2089 non-null   object
#  5   rating_numerator    2092 non-null   float64
#  6   rating_denominator  2092 non-null   int64
#  7   name                2092 non-null   object
#  8   dog_stage           2092 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(6)
# memory usage: 243.4+ KB

# %% [markdown]
# ### Issue #11: df1, df2 and df3 should form a single table

# %% [markdown]
# #### Define
# Merge df1, df2 and df3 into a single column based on columns common to all of them (`tweet_id`, `tweet_id` and `id` respectively)

# %% [markdown]
# #### Code

# %%
df1_copy.head(2)
# Out:
#              tweet_id                 timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...              13.0
# 1  https://twitter.com/dog_rates/status/892177421...              13.0
#
#    rating_denominator     name dog_stage
# 0                  10  Phineas   Unknown
# 1                  10    Tilly   Unknown

# %%
df2_copy.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#   img_num                   breed      conf
# 0       1  Welsh_springer_spaniel  0.465074
# 1       1                 redbone  0.506826
# 2       1         German_shepherd  0.596461
# 3       1     Rhodesian_ridgeback  0.408143
# 4       1      miniature_pinscher  0.560311

# %%
#merging df1_copy and df2_copy
df_merge = pd.merge(df1_copy,df2_copy,left_on="tweet_id",right_on="tweet_id")

# %%
#merging df_merge and df3_copy
final_df =  pd.merge(df_merge,df3_copy,left_on="tweet_id",right_on="id")

# %%
final_df.head()
# Out:
#              tweet_id                 timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 1  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 2  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 3  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# 4  891087950875897856 2017-07-29 00:08:17+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Tilly. She's just checking pup on you....
# 1  This is Archie. He is a rare Norwegian Pouncin...
# 2  This is Darla. She commenced a snooze mid meal...
# 3  This is Franklin. He would like you to stop ca...
# 4  Here we have a majestic great white breaching ...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892177421...              13.0
# 1  https://twitter.com/dog_rates/status/891815181...              12.0
# ...

# %%
final_df.drop(['id','expanded_urls'], axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1577 entries, 0 to 1576
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1577 non-null   object
#  1   timestamp           1577 non-null   datetime64[ns, UTC]
#  2   source              1577 non-null   object
#  3   text                1577 non-null   object
#  4   rating_numerator    1577 non-null   float64
#  5   rating_denominator  1577 non-null   int64
#  6   name                1577 non-null   object
#  7   dog_stage           1577 non-null   object
#  8   jpg_url             1577 non-null   object
#  9   img_num             1577 non-null   category
#  10  breed               1577 non-null   object
#  11  conf                1577 non-null   float64
#  12  retweet_count       1577 non-null   int64
#  13  favorite_count      1577 non-null   int64
# ...

# %%
final_df.describe()
# Out:
#        rating_numerator  rating_denominator         conf  retweet_count  \
# count       1577.000000              1577.0  1577.000000    1577.000000
# mean          10.834673                10.0     0.549717    2318.614458
# std            1.762663                 0.0     0.298124    4258.212461
# min            2.000000                10.0     0.000014      11.000000
# 25%           10.000000                10.0     0.304902     492.000000
# 50%           11.000000                10.0     0.548018    1120.000000
# 75%           12.000000                10.0     0.821664    2631.000000
# max           14.000000                10.0     0.999956   70791.000000
#
#        favorite_count
# count     1577.000000
# mean      8160.488903
# std      12085.774720
# min         66.000000
# 25%       1735.000000
# 50%       3559.000000
# 75%      10268.000000
# max     144957.000000

# %%
final_df['breed'].nunique()
# Out:
# 113

# %% [markdown]
# #### Test

# %%
final_df.reset_index()
# Out:
#       index            tweet_id                 timestamp              source  \
# 0         0  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 1         1  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 2         2  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 3         3  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# 4         4  891087950875897856 2017-07-29 00:08:17+00:00  Twitter for iPhone
# ...     ...                 ...                       ...                 ...
# 1572   1572  666049248165822465 2015-11-16 00:24:50+00:00  Twitter for iPhone
# 1573   1573  666044226329800704 2015-11-16 00:04:52+00:00  Twitter for iPhone
# 1574   1574  666033412701032449 2015-11-15 23:21:54+00:00  Twitter for iPhone
# 1575   1575  666029285002620928 2015-11-15 23:05:30+00:00  Twitter for iPhone
# 1576   1576  666020888022790149 2015-11-15 22:32:08+00:00  Twitter for iPhone
#
# ...

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
final_df.to_csv('twitter_archive_master.csv',index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
df.sample(10)
# Out:
#                 tweet_id                  timestamp              source  \
# 209   833722901757046785  2017-02-20 17:00:04+00:00  Twitter for iPhone
# 293   818536468981415936  2017-01-09 19:14:36+00:00  Twitter for iPhone
# 1291  673350198937153538  2015-12-06 03:56:12+00:00  Twitter for iPhone
# 1406  670319130621435904  2015-11-27 19:11:49+00:00  Twitter for iPhone
# 800   708109389455101952  2016-03-11 01:56:49+00:00  Twitter for iPhone
# 461   783085703974514689  2016-10-03 23:25:55+00:00  Twitter for iPhone
# 1142  678399652199309312  2015-12-20 02:20:55+00:00  Twitter for iPhone
# 580   747594051852075008  2016-06-28 00:54:46+00:00  Twitter for iPhone
# 278   821407182352777218  2017-01-17 17:21:47+00:00  Twitter for iPhone
# 921   695794761660297217  2016-02-06 02:22:53+00:00  Twitter for iPhone
#
#                                                    text  rating_numerator  \
# 209   This is Bronte. She's fairly h*ckin aerodynami...              13.0
# ...

# %%
df.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator      img_num  \
# count  1.577000e+03       1577.000000              1577.0  1577.000000
# mean   7.385129e+17         10.834673                10.0     1.207356
# std    6.945413e+16          1.762663                 0.0     0.563930
# min    6.660209e+17          2.000000                10.0     1.000000
# 25%    6.766034e+17         10.000000                10.0     1.000000
# 50%    7.088458e+17         11.000000                10.0     1.000000
# 75%    7.960315e+17         12.000000                10.0     1.000000
# max    8.921774e+17         14.000000                10.0     4.000000
#
#               conf  retweet_count  favorite_count
# count  1577.000000    1577.000000     1577.000000
# mean      0.549717    2318.614458     8160.488903
# std       0.298124    4258.212461    12085.774720
# min       0.000014      11.000000       66.000000
# 25%       0.304902     492.000000     1735.000000
# ...

# %%
df.breed.value_counts()
# Out:
# golden_retriever           146
# Labrador_retriever          93
# Chihuahua                   90
# Pembroke                    86
# pug                         59
#                           ...
# wire-haired_fox_terrier      1
# clumber                      1
# Japanese_spaniel             1
# Irish_wolfhound              1
# silky_terrier                1
# Name: breed, Length: 113, dtype: int64

# %%
df.rating_numerator.hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df,x="rating_numerator",binwidth=1)
# Out:
# <AxesSubplot:xlabel='rating_numerator', ylabel='Count'>

# %% [markdown]
# The rating_numerator distribution is left skewed. Most of the ratings are on the high side. The histogram above shows that 12/10 is the most common rating

# %% [markdown]
# ### Do dogs with high ratings have high retweet and favourite counts?

# %%
plt.scatter(df['retweet_count'], df['favorite_count'])
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
sns.scatterplot(y='retweet_count', x='favorite_count', data=df, hue='rating_numerator')
# Out:
# <AxesSubplot:xlabel='favorite_count', ylabel='retweet_count'>

# %%
plt.figure(figsize=(8,5))
df.breed.value_counts()[:10].sort_values().plot(kind="barh")
plt.title("Top 10 Most Popular Dogs")
# Out:
# Text(0.5, 1.0, 'Top 10 Most Popular Dogs')

# %%
df.dog_stage.value_counts().sort_values().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
popular_breeds = df.breed.value_counts()[:10]
popular_breeds.index
# Out:
# Index(['golden_retriever', 'Labrador_retriever', 'Chihuahua', 'Pembroke',
#        'pug', 'toy_poodle', 'chow', 'Samoyed', 'Pomeranian', 'malamute'],
#       dtype='object')

# %%
Avg_rating_per_breed = df.groupby(['breed'])['rating_numerator'].mean().sort_values(ascending=False)
Avg_rating_per_breed[:30]
# Out:
# breed
# Bouvier_des_Flandres          13.000000
# Saluki                        13.000000
# briard                        12.333333
# Tibetan_mastiff               12.250000
# Border_terrier                12.142857
# standard_schnauzer            12.000000
# silky_terrier                 12.000000
# Gordon_setter                 11.750000
# Irish_setter                  11.750000
# Samoyed                       11.750000
# golden_retriever              11.561644
# Pembroke                      11.546512
# Australian_terrier            11.500000
# Great_Pyrenees                11.466667
# chow                          11.444444
# kelpie                        11.416667
# cocker_spaniel                11.413793
# Eskimo_dog                    11.409091
# Leonberg                      11.333333
# Norfolk_terrier               11.333333
# Irish_water_spaniel           11.333333
# Greater_Swiss_Mountain_dog    11.333333
# Doberman                      11.333333
# ...

# %%
pop_breed_rating = Avg_rating_per_breed[['golden_retriever', 'Labrador_retriever', 'Chihuahua', 'Pembroke',
       'pug', 'toy_poodle', 'chow', 'Samoyed', 'Pomeranian', 'malamute']].sort_values()

# %%
pop_breed_rating.plot(kind="barh")
plt.xlabel("Rating")
# Out:
# Text(0.5, 0, 'Rating')

# %% [markdown]
# Amongst the top 10 most popular dog breeds, Samoyed, Golden Retriever and Pembroke have the 3 highest rating

# %%
Avg_rating_per_breed = df.groupby(['dog_stage'])['favorite_count'].mean().sort_values(ascending=False)
Avg_rating_per_breed
# Out:
# dog_stage
# puppo      22876.631579
# doggo      19429.647059
# floofer    12623.571429
# Unknown     7680.596269
# pupper      6644.743750
# Name: favorite_count, dtype: float64

# %%
Avg_rating_per_breed = df.groupby(['dog_stage'])['retweet_count'].mean().sort_values(ascending=False)
Avg_rating_per_breed
# Out:
# dog_stage
# doggo      6466.862745
# puppo      6361.894737
# floofer    4095.142857
# Unknown    2133.532090
# pupper     1988.562500
# Name: retweet_count, dtype: float64

# %%
final_df.breed.value_counts()[:30]
# Out:
# golden_retriever                  146
# Labrador_retriever                 93
# Chihuahua                          90
# Pembroke                           86
# pug                                59
# toy_poodle                         46
# chow                               45
# Pomeranian                         40
# Samoyed                            40
# malamute                           33
# cocker_spaniel                     29
# French_bulldog                     29
# Chesapeake_Bay_retriever           29
# miniature_pinscher                 23
# Eskimo_dog                         22
# Cardigan                           20
# Siberian_husky                     20
# Staffordshire_bullterrier          19
# beagle                             19
# German_shepherd                    19
# Shih-Tzu                           19
# Rottweiler                         18
# Maltese_dog                        18
# Shetland_sheepdog                  17
# basset                             17
# ...

# %%
plt.figure(figsize=(8,5))
df.groupby(['breed'])['favorite_count'].sum().sort_values(ascending=False)[:10].plot(kind='barh')
plt.xlabel("Favourite Count")
plt.title("Top 10 Breeds by Favourite Count")
# Out:
# Text(0.5, 1.0, 'Top 10 Breeds by Favourite Count')

# %%
plt.figure(figsize=(8,5))
df.groupby(['breed'])['retweet_count'].sum().sort_values(ascending=False)[:10].plot(kind='barh')
plt.xlabel("Retweet Count")
plt.title("Top 10 Breeds by Retweet Count")
# Out:
# Text(0.5, 1.0, 'Top 10 Breeds by Retweet Count')

# %%
favourite_breeds = df.groupby(['breed'])['favorite_count','retweet_count'].sum().sort_values(by='favorite_count',ascending=False)
favourite_breeds
# Out:
#                     favorite_count  retweet_count
# breed
# golden_retriever           1612101         454004
# Labrador_retriever          967052         287622
# Pembroke                    866833         225030
# Chihuahua                   667361         210129
# French_bulldog              485179         115930
# ...                            ...            ...
# Brabancon_griffon             2240            684
# groenendael                   1958            442
# standard_schnauzer            1695            722
# Irish_wolfhound               1290            657
# Japanese_spaniel              1117            355
#
# [113 rows x 2 columns]

# %%
df.dog_stage.value_counts(normalize=True)
# Out:
# Unknown    0.849715
# pupper     0.101458
# doggo      0.032340
# puppo      0.012048
# floofer    0.004439
# Name: dog_stage, dtype: float64

# %%
df.source.value_counts()
# Out:
# Twitter for iPhone    1553
# Twitter Web Client      22
# TweetDeck                2
# Name: source, dtype: int64

# %% [markdown]
# ### Insights:
# 1. There is a strong positive relationship between retweet count and favourite counts.
#
# 2. Dogs with high retweet and favourite counts have high rating as well
#
# 3. Top 10 most popular breed of dogs are Golden retriever, Labrador retriever, Chihuahua, Pembroke, Pug, Toy poodle, Chow, Samoyed, Pomeranian and  Malamute
#
# 4. Amongst the top 10 most popular dog breeds, Samoyed, Golden Retriever and Pembroke have the top 3 rating
#
# 5. About 98.5% of WeRateDogs tweets are from an iPhone

# %% [markdown]
# ### Visualization
